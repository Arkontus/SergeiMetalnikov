# %% [markdown]
# # Домашнее задание 2
#
# 1. Даны два целых числа A и B (при этом A≤B). Выведите все числа от A до B включительно.Например, А=1 и В=5, тогда на печать должно быть выведено: 1 2 3 4 5
# - Программно создайте список из четных отрицательных чисел от -10 до -2: lst = [-10, -8, -6, -4, -2 ]
# - Создайте список из 3-х элементов и каждый элемент является также кортежем, состоящим из 2 случайных целых чисел.
# - Из списка c 10 элементами верните кортеж из 3-х списков с случайным количеством элементов (до 5 включительно) и случайными элементами из исходного массива.
# - Дан список строк: lst=["a","bb","ccc"]. Дополните каждую строку числом 0 перед строкой суммарно до 5 элементов. В результате должна получиться строка lst_result = ["0000a","000bb","00ccc"]
# - Дан список строк lst=["sergey@gmail.com", "ivan@gmail.com","dmitry@gmail.com"]. Из каждой строки удалите подстроку "@gmail.com", и оставшиеся имена объедините в одну строку через пробел. В результате должна получиться строка: "sergey ivan dmitry"
# - Дано два числа:  aa  и  bb . Найдите гипотенузу треугольника с заданными катетами.
# - Дано трехзначное число. Найдите сумму его цифр
# - Выведите все элементы списка с четными индексами (то есть A[0], A[2], A[4], ...). Например, дан список lst =[1,2,3,4,5], тогда должна быть напечатана строка: 1 3 5
#
# Задание со звездочкой
# - Реализуйте [сортировку пузырьком](https://ru.wikipedia.org/wiki/%D0%A1%D0%BE%D1%80%D1%82%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B0_%D0%BF%D1%83%D0%B7%D1%8B%D1%80%D1%8C%D0%BA%D0%BE%D0%BC)
#
# В случае возникновения вопросов по данным заданиям прошу писать на email: **aparinov1@gmail.com**, указывая в качестве темы письма строку **"Py4DM"**
